# %%
import pandas

# %%
df = pandas.read_csv('data/mof-direct-tender-2015.csv',index='title,')

# %%
df.sort('company',ascending=True)
# Out:
#                                                  title  \
# 41   PERMOHONAN KELULUSAN UNTUK PEROLEHAN SECARA RU...
# 1    PERMOHONAN PEROLEHAN SECARA RUNDINGAN TERUS BA...
# 102  PERMOHONAN UNTUK RUNDINGAN TERUS BAGI PROMOSI ...
# 20   PERMOHONAN KELULUSAN PEROLEHAN SECARA RUNDINGA...
# 109  PERMOHONAN PEROLEHAN SECARA RUNDINGAN TERUS BA...
# 55   RUNDINGAN TERUS BAGI MEMBEKAL, MENGHANTAR, MEM...
# 138  PERMOHONAN RUNDINGAN TERUS BAGI TAWARAN UNIVER...
# 52   PELANJUTAN KONTRAK SYARIKAT ALAM TEKNOKRAT SDN...
# 54   PERMOHONAN UNTUK MELAKSANAKAN PERKHIDMATAN PEN...
# 116  PERMOHONAN KELULUSAN PEROLEHAN SECARA RUNDINGA...
# 93   PERMOHONAN PEROLEHAN SEBELAS (11) UNIT MESIN F...
# 18   PERMOHONAN KELULUSAN SECARA RUNDINGAN TERUS BA...
# 82   CADANGAN PERTAMBAHAN LESEN HUMAN RESOURCE USER...
# 47   PELANTIKAN PENYELIA PERKHIDMATAN PENGKOMERSILA...
# 105  PERMOHONAN BAGI MEWUJUDKAN KONTRAK PENYIMPANAN...
# 9    PERMOHONAN KELULUSAN KHAS BAGI PELANTIKAN CENT...
# ...

# %%
#Limit to those 10 million

# %%
df_bigbucks = df.loc[df['value'] >= 10000000]

# %%
df_bigbucks.sort('value', ascending=False)
# Out:
#                                                  title  \
# 71   PERMOHONAN PELANJUTAN KONTRAK BAGI PELAKSANAAN...
# 21   PERMOHONAN RUNDINGAN TERUS BAGI PELANTIKAN SEM...
# 131  PERKHIDMATAN MAINTENANCE, REPAIR AND OVERHAUL ...
# 26   PROGRAM PERUMAHAN RAKYAT (PPR) JABATAN PERUMAH...
# 25   PROGRAM PERUMAHAN RAKYAT (PPR) JABATAN PERUMAH...
# 24   PROGRAM PERUMAHAN RAKYAT (PPR) JABATAN PERUMAH...
# 27   PROJEK MENAIK TARAF TERMINAL PENUMPANG DAN JET...
# 23   PROGRAM PERUMAHAN RAKYAT (PPR) JABATAN PERUMAH...
# 115  PERMOHONAN CADANGAN PROJEK PENINGKATAN KEUPAYA...
# 69   PERMOHONAN PEMBEKALAN 26,000 UNIT TANGKI AIR J...
# 7    PERMOHONAN KELULUSAN PEROLEHAN SECARA RUNDINGA...
# 70   PEROLEHAN SECARA RUNDINGAN TERUS BAGI PERKHIDM...
# 6    PERMOHONAN KELULUSAN KEMENTERIAN KEWANGAN BAGI...
# 106  PERMOHONAN KELULUSAN SEWAAN PERKHIDMATAN PRASA...
# 114  PERMOHONAN KELULUSAN PEROLEHAN PEMBANGUNAN SIS...
# 28   PERMOHONAN RUNDINGAN TERUS PROJEK PEMBINAAN TA...
# ...

# %%
#We have 20 projects
len(df_bigbucks)
# Out:
# 20

# %%
#value of projects above RM10 Million
df_bigbucks['value'].sum()
# Out:
# 1556367166

# %%
#value of all projects
df['value'].sum()
# Out:
# 1709783318
